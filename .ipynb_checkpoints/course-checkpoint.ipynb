# %%
import numpy as np
import pandas as pd

# %%
DATASET_PATH = './train.csv'
PREPARED_DATASET_PATH = './train_prepared.csv'

# %%
df = pd.read_csv(DATASET_PATH, sep=',')

# %% [markdown]
# # Уменьшение объема памяти датасета

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col]. astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
                       
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                       df[col] = df[col].astype(np.float32)
                else:
                       df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:1f}%'.format(100 * (start_mem - end_mem) / start_mem))
                       
    return df

# %% [markdown]
# # Визуализация данных

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
matplotlib.rcParams.update({'font.size': 14}) # размер шрифта на всех графиках

# %%
plt.figure(figsize = (16, 8))

plt.subplot(121)
df['Price'].hist(density=False, bins=20)
plt.xlabel('Price')
plt.ylabel('count')

plt.subplot(122)
sns.kdeplot(df['Price'], shade=True, legend=False)
plt.xlabel('Price')

plt.suptitle('Distiribution of price_houses')
plt.show()

# %%
target_mean = round(df['Price'].mean(), 2)
target_median = df['Price'].median()
target_mode = round(df['Price'].mode()[0], 2)
target_mean, target_median, target_mode
# Out:
# (214138.86, 192269.64487934904, 59174.78)

# %%
plt.figure(figsize = (16, 8))

sns.distplot(df['Price'], bins=50)

y = np.linspace(0, 0.000005, 10)
plt.plot([target_mean] * 10, y, label='mean', linewidth=4)
plt.plot([target_median] * 10, y, label='median', linewidth=4)
plt.plot([target_mode] * 10, y, label='mode', linewidth=4)

plt.title('Distribution of price_house')
plt.legend()
plt.show()

# %% [markdown]
# ### Анализ признаков

# %%
df_num_features = df.select_dtypes(include=['float64', 'float32', 'float16'])
df_num_features.drop('Price', axis=1, inplace=True)

# %%
df_num_features.head()
# Out:
#    Rooms      Square  LifeSquare  KitchenSquare  HouseFloor  Ecology_1  \
# 0    3.0  115.027311         NaN           10.0        10.0   0.075424
# 1    1.0   39.832524   23.169223            8.0         8.0   0.118537
# 2    3.0   78.342215   47.671972           10.0        17.0   0.025609
# 3    1.0   40.409907         NaN            1.0        22.0   0.007122
# 4    2.0   64.285067   38.562517            9.0        16.0   0.282798
#
#    Healthcare_1
# 0           NaN
# 1        1183.0
# 2         240.0
# 3           NaN
# 4           NaN

# %%
df_num_features.hist(figsize=(16, 16), bins=10, grid=False)
plt.show()

# %%
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.4)

corr_matrix = df.corr()
corr_matrix = np.round(corr_matrix, 2)
corr_matrix[np.abs(corr_matrix) < 0.4] = 0

sns.heatmap(corr_matrix, annot=True, linewidth=.5, cmap='coolwarm')

plt.title('Colleration matrix')
plt.show()

# %% [markdown]
# ### Обработка NaN

# %%
df['LifeSquare_nan'] = 0
df.loc[df['LifeSquare'].isna(), 'LifeSquare_nan'] = 1

# %%
df['Healthcare_1_nan'] = 0
df.loc[df['Healthcare_1'].isna(), 'Healthcare_1_nan'] = 1

# %%
medians = df[['LifeSquare', 'Healthcare_1']].median()
medians
# Out:
# LifeSquare       32.78126
# Healthcare_1    900.00000
# dtype: float64

# %%
df[['LifeSquare', 'Healthcare_1']] = df[['LifeSquare', 'Healthcare_1']].fillna(medians)

# %% [markdown]
# ### Обработка выбросов

# %% [markdown]
# #### Количество комнат

# %%
rooms_max_value = np.quantile(df['Rooms'], q=0.99)
rooms_max_value
# Out:
# 4.0

# %%
rooms_min_value = np.quantile(df['Rooms'], q=0.025)
rooms_min_value
# Out:
# 1.0

# %%
condition = (df['Rooms'] > rooms_max_value) | (df['Rooms'] < rooms_min_value)
df['Rooms_outlier'] = 0
df.loc[condition, 'Rooms_outlier'] = 1
df.loc[condition, ['Rooms']] = df['Rooms'].median()
df['Rooms'].describe()
# Out:
# count    10000.000000
# mean         1.883000
# std          0.800234
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          4.000000
# Name: Rooms, dtype: float64

# %% [markdown]
# #### Площадь квартиры

# %%
square_max_value = np.quantile(df['Square'], q=0.997)
square_max_value
# Out:
# 139.0738142000321

# %%
square_min_value = np.quantile(df['Square'], q=0.002)
square_min_value
# Out:
# 19.925535701033183

# %%
condition = (df['Square'] > square_max_value) | (df['Square'] < square_min_value)
df[condition]
# Out:
#       DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 161           45    1.0    2.954309    5.257278            1.0      3
# 328           27    3.0    4.390331    5.610772            1.0      8
# 403           13    2.0  183.382273  100.985505           15.0      2
# 726            9    2.0  604.705972   32.781260            1.0     17
# 730           62    3.0  156.636577  153.685835            1.0      1
# 1401           5    1.0    5.129222    5.549458            1.0      1
# 1449          93    3.0  169.117203   32.781260            1.0      5
# 1606          56    3.0  190.857689  107.376164           19.0      7
# 1776          27    4.0  200.334539  201.627361           25.0      1
# 1906          86    2.0  275.645284  233.949309           26.0     12
# 2066         183    4.0  151.150660   98.187482           23.0      6
# 2516          46    2.0  147.709302   32.781260            0.0      6
# 2790         129    4.0  185.906396   84.830074           31.0      5
# 3182          24    4.0  155.930023   76.831293           15.0      6
# 3204          23    3.0  163.495333  161.504222           12.0      5
# 3686          57    3.0   16.547242   16.698571            8.0      5
# 4444          93    3.0  169.385184   32.781260            1.0      2
# 4496          34    1.0    1.988943    2.642219            1.0     21
# 4613          27    4.0  140.242987   85.634041           10.0      6
# 4800          38    1.0    4.502784    4.618547            1.0     28
# 5009          27    1.0    4.633498    1.969969            1.0     18
# 5258          17    4.0  170.016872   32.781260            0.0     12
# 5283         151    1.0  174.649522  174.837082           15.0     10
# 5764          54    1.0  168.086347  125.486563           30.0     18
# 5844          93    3.0  167.767027   32.781260            1.0      1
# 5870          21    1.0   16.117154    8.822988            0.0      2
# 6030          23    1.0  163.286965  161.155275            1.0      4
# 6450          30    3.0  162.587886  164.526757            0.0      2
# 6632           0    1.0   17.498542   13.446544            0.0      7
# 6909          23    1.0  148.179026   32.781260            1.0      1
# 7010         102    1.0  409.425181  410.639749           10.0      4
# 7033          88    2.0    5.497061   67.628717            1.0     24
# 7470           1    1.0    1.136859    4.525736            1.0      3
# 7644          27    2.0  212.932361  211.231125            0.0      2
# 8011         129    4.0  186.692602   87.487080           32.0      3
# 8044          93    2.0  170.379494   32.781260            1.0      3
# 8330         101    1.0   18.509177   15.170851            3.0      5
# 8501          62    2.0   17.414181   32.781260            1.0      4
# 8572           6    1.0    2.596351    4.604943            1.0      3
# 8805          27    1.0    4.380726   40.805837            1.0     10
# 8872          30    3.0  169.509941  170.713651            1.0      2
# 9037          23    1.0  160.647588   32.781260            1.0      3
# 9067           1    3.0    4.823679   79.767964            0.0      6
# 9229          30    2.0  641.065193  638.163193           10.0     20
# 9286          81    3.0   13.784865   15.988889            7.0      4
# 9307          23    2.0  198.930182  123.139863           10.0      1
# 9349         150    1.0   17.046188   20.036232            8.0      7
# 9846          23    2.0  148.671938  100.201652            1.0      1
# 9869          27    2.0    2.377248    0.873147            0.0      1
# 9990          21    1.0   18.983962   11.419796            2.0      1
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  Social_3  \
# 161          1.0       1977   0.195781          0  ...         6
# 328         19.0       2016   0.211401          0  ...         0
# 403          6.0       1997   0.090799          0  ...         2
# 726         18.0       1977   0.161532          0  ...         1
# 730          3.0       2005   0.072158          0  ...         1
# 1401         1.0       1977   0.150818          0  ...         4
# 1449         3.0       1977   0.004949          0  ...         0
# 1606         3.0       2007   0.000000          0  ...         4
# 1776         2.0       2013   0.041116          0  ...         4
# 1906        37.0       2011   0.161976          0  ...         5
# 2066         7.0       1912   0.037316          0  ...        93
# 2516         0.0       1977   0.150818          0  ...         4
# 2790         3.0       2015   0.020741          0  ...         5
# 3182        22.0       2012   0.111627          0  ...         8
# 3204         3.0       1977   0.014073          0  ...         0
# 3686         5.0       1962   0.133215          0  ...         3
# 4444        10.0       1977   0.004949          0  ...         0
# 4496         4.0       1977   0.069753          0  ...         4
# 4613        12.0       2008   0.051815          0  ...         0
# 4800         1.0       1977   0.060753          0  ...         2
# 5009         1.0       1977   0.011654          0  ...         0
# 5258         0.0       1977   0.093443          0  ...         5
# 5283        12.0       1958   0.236108          0  ...        27
# 5764        28.0       2011   0.006076          0  ...         0
# 5844         1.0       1977   0.004949          0  ...         0
# 5870         5.0       1965   0.194489          0  ...         3
# 6030         3.0       1977   0.014073          0  ...         0
# 6450         3.0       1977   0.000078          0  ...       141
# 6632         5.0       1961   0.319809          0  ...        16
# 6909         2.0       1977   0.014073          0  ...         0
# 7010         4.0       2016   0.238617          0  ...         6
# 7033        22.0       1977   0.127376          0  ...         3
# 7470         1.0       1977   0.007122          0  ...         0
# 7644         3.0       2008   0.211401          0  ...         0
# 8011         3.0       2011   0.020741          0  ...         5
# 8044         2.0       1977   0.004949          0  ...         0
# 8330         5.0       1970   0.225825          1  ...         7
# 8501        20.0       1977   0.072158          0  ...         1
# 8572        25.0       2014   0.243205          0  ...         0
# 8805        17.0       2013   0.211401          0  ...         0
# 8872         2.0       2018   0.000078          0  ...       141
# 9037         3.0       1977   0.014073          0  ...         0
# 9067        17.0       1977   0.007122          0  ...         0
# 9229        19.0       2019   0.000078          0  ...       141
# 9286         5.0       1960   0.319809          0  ...        16
# 9307         2.0       2011   0.014073          0  ...         0
# 9349        12.0       1982   0.300323          0  ...         6
# 9846         3.0       2013   0.014073          0  ...         0
# 9869         0.0       1977   0.017647          0  ...         0
# 9990         5.0       1967   0.194489          0  ...         3
#
#       Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price  \
# 161          900.0            3        2        0  438005.182323
# 328          900.0            0        1        0  161379.067034
# 403          900.0            5       15        0  622888.825328
# 726           30.0            2        4        0  187717.242538
# 730          900.0            0        0        1  502523.573863
# 1401        2643.0            4        5        0  369472.403061
# 1449         900.0            0        0        0  211325.577641
# 1606         900.0            2        6        0  338644.075979
# 1776         900.0            1        4        0  528560.506016
# 1906        4508.0            3        7        0  455264.882666
# 2066         562.0            4       10        0  284884.959104
# 2516        2643.0            4        5        0  352168.955975
# 2790        1340.0            2        5        0  340273.238253
# 3182        1970.0            2        3        0  559886.965348
# 3204         900.0            0        0        0  207007.956663
# 3686        1406.0            3        4        1   77835.185808
# 4444         900.0            0        0        0  190949.293998
# 4496         900.0            1       11        0  458378.777006
# 4613         900.0            0        0        0  342859.739448
# 4800         520.0            0        7        0  483283.488083
# 5009         900.0            0        0        0  107604.269441
# 5258        3300.0            2        4        0  531049.721966
# 5283         900.0            3       10        0  232766.187698
# 5764         645.0            6        6        0  367353.574566
# 5844         900.0            0        0        0  211180.794219
# 5870         125.0            3        5        0   79913.267856
# 6030         900.0            0        0        0  228572.520347
# 6450        1046.0            3       23        0  207407.352593
# 6632        2857.0            5        8        0   88871.750230
# 6909         900.0            0        0        0  160902.854650
# 7010         705.0            3        6        0   90470.430830
# 7033         900.0            3        9        0  412511.088764
# 7470         900.0            0        1        0  181434.825589
# 7644         900.0            0        1        0  302211.260887
# 8011        1340.0            2        5        0  423443.464367
# 8044         900.0            0        0        0  194582.912756
# 8330        1548.0            3        2        0  115845.861527
# 8501         900.0            0        0        1  180750.471749
# 8572         540.0            0        0        0  137597.601458
# 8805         900.0            0        1        0   97560.720383
# 8872        1046.0            3       23        0  200800.673767
# 9037         900.0            0        0        0  217874.997452
# 9067         900.0            0        1        0  237716.681261
# 9229        1046.0            3       23        0  133529.681562
# 9286        2857.0            5        8        0   78388.806186
# 9307         900.0            0        0        0  345665.209100
# 9349         900.0            1        9        0   74222.110465
# 9846         900.0            0        0        0  152464.848743
# 9869         900.0            0        0        0  126596.941798
# 9990         125.0            3        5        0  112411.221700
#
#       LifeSquare_nan  Healthcare_1_nan  Social_1_2  Rooms_outlier
# 161                0                 1      49.060              0
# 328                0                 1      18.460              0
# 403                0                 1     169.415              1
# 726                1                 0      53.240              0
# 730                0                 1       5.145              0
# 1401               0                 0      33.165              0
# 1449               1                 1       0.930              0
# 1606               0                 1      48.335              0
# 1776               0                 1     127.460              0
# 1906               0                 0      66.050              1
# 2066               0                 0      65.740              0
# 2516               1                 0      33.165              1
# 2790               0                 0      52.065              0
# 3182               0                 0     111.190              0
# 3204               0                 1       4.375              0
# 3686               0                 0     105.975              0
# 4444               1                 1       0.930              0
# 4496               0                 1     121.350              0
# 4613               0                 1      11.135              0
# 4800               0                 0      28.935              0
# 5009               0                 1       8.575              0
# 5258               1                 0      46.175              0
# 5283               0                 1      35.465              0
# 5764               0                 0      56.425              0
# 5844               1                 1       0.930              0
# 5870               0                 0      87.020              0
# 6030               0                 1       4.375              0
# 6450               0                 0      53.990              0
# 6632               0                 0      48.780              0
# 6909               1                 1       4.375              0
# 7010               0                 0      45.445              0
# 7033               0                 1      85.145              0
# 7470               0                 1       2.320              0
# 7644               0                 1      18.460              1
# 8011               0                 0      52.065              0
# 8044               1                 1       0.930              0
# 8330               0                 0      73.790              0
# 8501               1                 1       5.145              0
# 8572               0                 0      12.820              0
# 8805               0                 1      18.460              0
# 8872               0                 0      53.990              0
# 9037               1                 1       4.375              0
# 9067               0                 1       2.320              0
# 9229               0                 0      53.990              0
# 9286               0                 0      48.780              0
# 9307               0                 1       4.375              1
# 9349               0                 1     103.555              0
# 9846               0                 1       4.375              0
# 9869               0                 1       4.345              1
# 9990               0                 0      87.020              0
#
# [50 rows x 21 columns]

# %%
df['Square_outlier'] = 0
df.loc[condition, 'Square_outlier'] = 1

# %%
df.loc[condition, 'Square'] = df['Square'].median()
df['Square'].describe()
# Out:
# count    10000.000000
# mean        55.925578
# std         17.970566
# min         19.927423
# 25%         41.810536
# 50%         52.513310
# 75%         65.805516
# max        139.070296
# Name: Square, dtype: float64

# %% [markdown]
# #### Жилая площадь

# %%
df['LifeSquare'].describe()
# Out:
# count    10000.000000
# mean        36.266040
# std         76.609981
# min          0.370619
# 25%         25.527399
# 50%         32.781260
# 75%         41.427234
# max       7480.592129
# Name: LifeSquare, dtype: float64

# %%
lifesquare_max_value = np.quantile(df['LifeSquare'], q=0.975)
lifesquare_max_value
# Out:
# 78.3859441855343

# %%
lifesquare_min_value = np.quantile(df['LifeSquare'], q=0.025)
lifesquare_min_value
# Out:
# 15.146123972262354

# %%
condition = (df['LifeSquare'] < lifesquare_min_value) | (df['LifeSquare'] > lifesquare_max_value)
df[condition]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 26     8553          88    3.0  83.262530    4.769174            1.0     13
# 32     3876         100    4.0  52.513310   79.316650            8.0      4
# 64     3992           1    3.0  87.200625   87.730225            0.0     21
# 100   13343          74    2.0  79.937665   82.931595            1.0      8
# 119    5112           6    2.0  63.591740    0.795539           10.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 9960  16258          48    3.0  96.056784   98.152802            1.0     15
# 9965   6441          52    3.0  85.796885   85.305246            0.0     15
# 9982  10268          27    1.0  36.112393    1.855415            1.0      9
# 9990  10635          21    1.0  52.513310   11.419796            2.0      1
# 9993   9289           1    3.0  84.486078   88.931509            0.0      4
#
#       HouseFloor  HouseYear  Ecology_1  ... Social_3 Healthcare_1  \
# 26           1.0       1977   0.127376  ...        3        900.0
# 32           8.0       1960   0.200147  ...        8        770.0
# 64          22.0       1977   0.007122  ...        0        900.0
# 100         21.0       1977   0.075779  ...        3        900.0
# 119         17.0       2014   0.243205  ...        0        540.0
# ...          ...        ...        ...  ...      ...          ...
# 9960         1.0       2017   0.041125  ...        5        900.0
# 9965        17.0       1977   0.371149  ...        1        750.0
# 9982        16.0       1977   0.211401  ...        0        900.0
# 9990         5.0       1967   0.194489  ...        3        125.0
# 9993        22.0       2016   0.007122  ...        0        900.0
#
#       Helthcare_2  Shops_1  Shops_2          Price  LifeSquare_nan  \
# 26              3        9        B  410883.892020               0
# 32              2        0        B  600903.828562               0
# 64              0        1        B  300180.365669               0
# 100             0        2        B  226808.747168               0
# 119             0        0        B  174741.998061               0
# ...           ...      ...      ...            ...             ...
# 9960            1       10        B  524365.550705               0
# 9965            2        5        B  204462.983720               0
# 9982            0        1        B   94881.691800               0
# 9990            3        5        B  112411.221700               0
# 9993            0        1        B  264213.558631               0
#
#       Healthcare_1_nan Rooms_outlier  Square_outlier
# 26                   1             0               0
# 32                   0             0               1
# 64                   1             0               0
# 100                  1             0               0
# 119                  0             0               0
# ...                ...           ...             ...
# 9960                 1             0               0
# 9965                 0             0               0
# 9982                 1             0               0
# 9990                 0             0               1
# 9993                 1             0               0
#
# [500 rows x 24 columns]

# %%
df['LifeSquare_outlier'] = 0
df.loc[condition, 'LifeSquare_outlier'] = 1

# %%
df.loc[condition, 'LifeSquare'] = (df['LifeSquare'] / df['Square']).median() * df['Square']
round(df['LifeSquare'], 0).describe()
# Out:
# count    10000.000000
# mean        34.932800
# std         11.767937
# min         15.000000
# 25%         28.000000
# 50%         33.000000
# 75%         41.000000
# max         78.000000
# Name: LifeSquare, dtype: float64

# %% [markdown]
# #### Кухни

# %%
kitchen_max_value = np.quantile(df['KitchenSquare'], q=0.99)
kitchen_max_value
# Out:
# 16.0

# %%
df['KitchenSquare'].value_counts()
# Out:
# 1.0       2460
# 8.0       1306
# 5.0       1169
# 10.0      1075
# 6.0       1038
# 9.0        843
# 0.0        697
# 7.0        609
# 12.0       249
# 11.0       233
# 13.0        67
# 14.0        51
# 4.0         39
# 15.0        31
# 3.0         22
# 16.0        16
# 20.0        14
# 17.0        12
# 19.0        11
# 18.0         6
# 2.0          4
# 22.0         3
# 30.0         2
# 43.0         2
# 41.0         2
# 112.0        2
# 25.0         2
# 51.0         2
# 37.0         2
# 58.0         2
# 32.0         2
# 21.0         1
# 73.0         1
# 75.0         1
# 36.0         1
# 27.0         1
# 63.0         1
# 1970.0       1
# 54.0         1
# 53.0         1
# 60.0         1
# 26.0         1
# 66.0         1
# 39.0         1
# 29.0         1
# 78.0         1
# 31.0         1
# 84.0         1
# 48.0         1
# 96.0         1
# 42.0         1
# 40.0         1
# 23.0         1
# 72.0         1
# 35.0         1
# 62.0         1
# 123.0        1
# 2014.0       1
# Name: KitchenSquare, dtype: int64

# %%
kitchen_min_value = np.quantile(df['KitchenSquare'], q=0.025)
kitchen_min_value
# Out:
# 0.0

# %%
condition = (df['KitchenSquare'] < kitchen_min_value) | (df['KitchenSquare'] > kitchen_max_value)
df[condition]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 277   13559          79    1.0  96.838013   49.140960           22.0     19
# 286    2737          27    3.0  52.513310   32.202550          123.0      5
# 456   10546          62    1.0  46.013187   43.417043           43.0      4
# 511    8685          62    2.0  52.513310   32.202550           30.0      5
# 682   16593          52    2.0  64.859242   32.781260           62.0     15
# ...     ...         ...    ...        ...         ...            ...    ...
# 9743  14754          23    3.0  52.513310   56.801439           20.0      2
# 9746   7857          27    2.0  43.956044   26.955008           19.0     15
# 9810  16408           9    1.0  40.226907   37.849083           19.0      8
# 9860   3431          62    2.0  60.715426   40.720961           25.0      5
# 9937   6149          53    4.0  52.513310   32.202550           20.0     12
#
#       HouseFloor  HouseYear  Ecology_1  ... Healthcare_1 Helthcare_2  Shops_1  \
# 277         24.0       2016   0.050756  ...        145.0           0        1
# 286         10.0       2015   0.017647  ...        900.0           0        0
# 456         17.0       2019   0.072158  ...        900.0           0        0
# 511          3.0       2017   0.072158  ...        900.0           0        0
# 682         17.0       1977   0.371149  ...        750.0           2        5
# ...          ...        ...        ...  ...          ...         ...      ...
# 9743         2.0       2017   0.014073  ...        900.0           0        0
# 9746        17.0       2006   0.075424  ...        900.0           0        0
# 9810        17.0       1993   0.161532  ...         30.0           2        4
# 9860        12.0       2012   0.386772  ...        900.0           0        0
# 9937        24.0       2018   0.049637  ...        229.0           1        3
#
#       Shops_2          Price  LifeSquare_nan  Healthcare_1_nan  Rooms_outlier  \
# 277         B  348962.861294               0                 0              0
# 286         B  234194.837047               0                 1              0
# 456         A  113909.099428               0                 1              0
# 511         A  271919.866048               0                 1              1
# 682         B  185993.474671               1                 0              0
# ...       ...            ...             ...               ...            ...
# 9743        B  231464.510346               0                 1              0
# 9746        B  143688.076514               0                 1              0
# 9810        B  137595.610782               0                 0              0
# 9860        A  172366.012197               0                 1              0
# 9937        B  492943.252891               0                 0              0
#
#      Square_outlier  LifeSquare_outlier
# 277               0                   0
# 286               1                   1
# 456               0                   0
# 511               1                   1
# 682               0                   0
# ...             ...                 ...
# 9743              1                   0
# 9746              0                   1
# 9810              0                   0
# 9860              0                   0
# 9937              1                   1
#
# [91 rows x 25 columns]

# %%
df['KitchenSquare_outlier'] = 0
df.loc[condition, 'KitchenSquare_outlier'] = 1

# %%
df.loc[condition, 'KitchenSquare'] = df['KitchenSquare'].median()
df['KitchenSquare'].describe()
# Out:
# count    10000.000000
# mean         5.621400
# std          3.779245
# min          0.000000
# 25%          1.000000
# 50%          6.000000
# 75%          9.000000
# max         16.000000
# Name: KitchenSquare, dtype: float64

# %% [markdown]
# ###### Жилая площадь > площади за вычетом кухни

# %%
df['NonresidentialSquare'] = df['Square'] - df['LifeSquare'] - df['KitchenSquare']
df['NonresidentialSquare'].describe()
# Out:
# count    10000.000000
# mean        14.600225
# std         11.956952
# min        -39.317983
# 25%          8.621456
# 50%         12.706299
# 75%         19.538822
# max         66.637482
# Name: NonresidentialSquare, dtype: float64

# %%
condition = (df['LifeSquare'] >= (df['Square'] - df['KitchenSquare']))

# %%
df.loc[condition, 'Square_outlier'] = 1

# %%
df.loc[condition, 'Square'] = df['LifeSquare'] + df['KitchenSquare'] + df['NonresidentialSquare'].median()

# %%
df['NonresidentialSquare'] = df['Square'] - df['LifeSquare'] - df['KitchenSquare']
df['NonresidentialSquare'].describe()
# Out:
# count    10000.000000
# mean        16.086256
# std         10.130851
# min          0.021395
# 25%          9.863840
# 50%         12.706817
# 75%         19.538822
# max         66.637482
# Name: NonresidentialSquare, dtype: float64

# %% [markdown]
# #### Этажность Дома

# %%
df['HouseFloor'].describe()
# Out:
# count    10000.000000
# mean        12.609400
# std          6.775974
# min          0.000000
# 25%          9.000000
# 50%         13.000000
# 75%         17.000000
# max        117.000000
# Name: HouseFloor, dtype: float64

# %%
housefloor_max_value = np.quantile(df['HouseFloor'], q=0.99)
housefloor_max_value
# Out:
# 25.0

# %%
condition = (df['HouseFloor'] > housefloor_max_value) | (df['HouseFloor'] == 0)

# %%
df['HouseFloor_outlier'] = 0
df.loc[condition, 'HouseFloor_outlier'] = 1

# %%
df.loc[condition, 'HouseFloor'] = df['HouseFloor'].median()

# %% [markdown]
# #### Корректировка этажности дома относительно этажа квартиры

# %%
df['Floor_outlier'] = 0

# %%
df.loc[(df['HouseFloor'] < df['Floor']), 'Floor_outlier'] = 1

# %%
df['Floor_outlier'].value_counts()
# Out:
# 0    8358
# 1    1642
# Name: Floor_outlier, dtype: int64

# %%
df.loc[(df['HouseFloor'] < df['Floor']), 'Floor']  = df['HouseFloor']

# %% [markdown]
# ### Возраст дома

# %%
df['HouseYear'].describe()
# Out:
# count    1.000000e+04
# mean     3.990166e+03
# std      2.005003e+05
# min      1.910000e+03
# 25%      1.974000e+03
# 50%      1.977000e+03
# 75%      2.001000e+03
# max      2.005201e+07
# Name: HouseYear, dtype: float64

# %%
house_year_min_value = np.quantile(df['HouseYear'], q=0.025)
house_year_min_value
# Out:
# 1959.0

# %%
condition = ((df['HouseYear'] < house_year_min_value) | (df['HouseYear'] > 2021))
df[condition]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 39     3736         167    2.0  56.712771   36.454064            7.0    5.0
# 50     9629         124    3.0  78.275227   58.330876            6.0    9.0
# 51    12774         157    2.0  62.747509   28.196813            8.0    5.0
# 106   12997           4    3.0  75.128389   52.754246            8.0    9.0
# 188    2574         159    2.0  43.439367   29.328888            6.0    5.0
# ...     ...         ...    ...        ...         ...            ...    ...
# 9919  16522          33    3.0  64.460827   42.088742            6.0    1.0
# 9927  15375         182    2.0  86.906324   65.200025            9.0    7.0
# 9955  16557          65    2.0  57.309254   34.105386            8.0   11.0
# 9961   7931         181    1.0  34.911269   18.433155            6.0   10.0
# 9997   2795         178    1.0  52.513310   16.555363            5.0    3.0
#
#       HouseFloor  HouseYear  Ecology_1  ...          Price LifeSquare_nan  \
# 39           5.0       1956   0.050272  ...  299177.502635              0
# 50           9.0       1953   0.169091  ...  387904.136320              0
# 51          10.0       1956   0.000000  ...  555661.943969              0
# 106          9.0       1956   0.000078  ...  574631.334051              0
# 188          8.0       1935   0.246624  ...  288674.665989              0
# ...          ...        ...        ...  ...            ...            ...
# 9919         5.0       1934   0.050272  ...  287607.336090              0
# 9927         8.0       1918   0.015017  ...  443270.817520              0
# 9955        11.0       1957   0.081943  ...  403476.612413              0
# 9961        12.0       1955   0.000000  ...  397528.736061              0
# 9997         5.0       1958   0.460556  ...  165953.912580              0
#
#       Healthcare_1_nan  Rooms_outlier  Square_outlier  LifeSquare_outlier  \
# 39                   0              0               0                   0
# 50                   1              0               0                   0
# 51                   0              0               0                   0
# 106                  0              0               0                   0
# 188                  1              0               0                   0
# ...                ...            ...             ...                 ...
# 9919                 0              0               0                   0
# 9927                 0              0               1                   0
# 9955                 1              0               0                   0
# 9961                 0              0               0                   0
# 9997                 1              0               1                   0
#
#       KitchenSquare_outlier  NonresidentialSquare HouseFloor_outlier  \
# 39                        0             13.258708                  0
# 50                        0             13.944351                  0
# 51                        0             26.550696                  0
# 106                       0             14.374144                  0
# 188                       0              8.110479                  0
# ...                     ...                   ...                ...
# 9919                      0             16.372086                  0
# 9927                      0             12.706299                  0
# 9955                      0             15.203869                  0
# 9961                      0             10.478114                  0
# 9997                      0             30.957946                  0
#
#       Floor_outlier
# 39                1
# 50                0
# 51                0
# 106               0
# 188               0
# ...             ...
# 9919              0
# 9927              0
# 9955              0
# 9961              0
# 9997              0
#
# [243 rows x 29 columns]

# %%
df['HouseYear_outlier'] = 0
df.loc[condition, 'HouseYear_outlier'] = 1

# %%
df.loc[condition, 'HouseYear'] = df['HouseYear'].median()

# %%
df['HouseYear'].describe()
# Out:
# count    10000.000000
# mean      1985.559800
# std         17.426893
# min       1959.000000
# 25%       1975.000000
# 50%       1977.000000
# 75%       2001.000000
# max       2020.000000
# Name: HouseYear, dtype: float64

# %% [markdown]
# ### Экология

# %%
df.loc[(df['Ecology_2'] == 'A'), 'Ecology_2'] = 1

# %%
df.loc[(df['Ecology_2'] == 'B'), 'Ecology_2']  = 0

# %%
df['Ecology_2'] = df['Ecology_2'].astype(int)

# %%
df.loc[(df['Ecology_3'] == 'A'), 'Ecology_3'] = 1

# %%
df.loc[(df['Ecology_3'] == 'B'), 'Ecology_3']  = 0

# %%
df['Ecology_3'] = df['Ecology_3'].astype(int)
df
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  115.027311   32.781260           10.0      4
# 1      3013          22    1.0   39.832524   23.169223            8.0      7
# 2      8215           1    3.0   78.342215   47.671972           10.0      2
# 3      2352           1    1.0   40.409907   32.781260            1.0     10
# 4     13866          94    2.0   64.285067   38.562517            9.0     16
# ...     ...         ...    ...         ...         ...            ...    ...
# 9995   1260          61    2.0   49.090728   33.272626            6.0      3
# 9996  16265          27    2.0   64.307684   37.038420            9.0     13
# 9997   2795         178    1.0   29.648057   16.555363            5.0      3
# 9998  14561          21    1.0   32.330292   22.326870            5.0      3
# 9999   7202          94    1.0   35.815476   22.301367            6.0      9
#
#       HouseFloor  HouseYear  Ecology_1  ...  Social_1  Social_2  Social_3  \
# 0           10.0       2014   0.075424  ...        11      3097         0
# 1            8.0       1966   0.118537  ...        30      6207         1
# 2           17.0       1988   0.025609  ...        33      5261         0
# 3           22.0       1977   0.007122  ...         1       264         0
# 4           16.0       1972   0.282798  ...        33      8667         2
# ...          ...        ...        ...  ...       ...       ...       ...
# 9995        12.0       1981   0.300323  ...        52     10311         6
# 9996         0.0       1977   0.072158  ...         2       629         1
# 9997         5.0       1958   0.460556  ...        20      4386        14
# 9998         9.0       1969   0.194489  ...        47      8004         3
# 9999         9.0       1975   0.127376  ...        43      8429         3
#
#       Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price  \
# 0            900.0            0        0        B  305018.871089
# 1           1183.0            1        0        B  177734.553407
# 2            240.0            3        1        B  282078.720850
# 3            900.0            0        1        B  168106.007630
# 4            900.0            0        6        B  343995.102962
# ...            ...          ...      ...      ...            ...
# 9995         900.0            1        9        B  119367.455796
# 9996         900.0            0        0        A  199715.148807
# 9997         900.0            1        5        B  165953.912580
# 9998         125.0            3        5        B  171842.411855
# 9999         900.0            3        9        B  177685.627486
#
#      LifeSquare_nan  Healthcare_1_nan
# 0                 1                 1
# 1                 0                 0
# 2                 0                 0
# 3                 1                 1
# 4                 0                 1
# ...             ...               ...
# 9995              0                 1
# 9996              0                 1
# 9997              0                 1
# 9998              0                 0
# 9999              0                 1
#
# [10000 rows x 22 columns]

# %% [markdown]
# ### Магазины

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     10000 non-null  int64
#  1   DistrictId             10000 non-null  int64
#  2   Rooms                  10000 non-null  float64
#  3   Square                 10000 non-null  float64
#  4   LifeSquare             10000 non-null  float64
#  5   KitchenSquare          10000 non-null  float64
#  6   Floor                  10000 non-null  float64
#  7   HouseFloor             10000 non-null  float64
#  8   HouseYear              10000 non-null  int64
#  9   Ecology_1              10000 non-null  float64
#  10  Ecology_2              10000 non-null  int32
#  11  Ecology_3              10000 non-null  int32
#  12  Social_1               10000 non-null  int64
#  13  Social_2               10000 non-null  int64
#  14  Social_3               10000 non-null  int64
#  15  Healthcare_1           10000 non-null  float64
#  16  Helthcare_2            10000 non-null  int64
#  17  Shops_1                10000 non-null  int64
#  18  Shops_2                10000 non-null  object
#  19  Price                  10000 non-null  float64
#  20  LifeSquare_nan         10000 non-null  int64
#  21  Healthcare_1_nan       10000 non-null  int64
#  22  Rooms_outlier          10000 non-null  int64
#  23  Square_outlier         10000 non-null  int64
#  24  LifeSquare_outlier     10000 non-null  int64
#  25  KitchenSquare_outlier  10000 non-null  int64
#  26  NonresidentialSquare   10000 non-null  float64
#  27  HouseFloor_outlier     10000 non-null  int64
#  28  Floor_outlier          10000 non-null  int64
#  29  HouseYear_outlier      10000 non-null  int64
# dtypes: float64(10), int32(2), int64(17), object(1)
# memory usage: 2.2+ MB

# %%
df.loc[df['Shops_2'] == 'A', 'Shops_2'] = 1
df.loc[df['Shops_2'] == 'B', 'Shops_2'] = 0

# %%
df['Shops_2'] = df['Shops_2'].astype(int)

# %%
df['Shops_2'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# # Исключение ненужных столбцов

# %%
df.drop(columns=['Id'], inplace=True)

# %%
df.head()
# Out:
#    DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0          27    3.0  115.027311   32.781260           10.0      4
# 1          22    1.0   39.832524   23.169223            8.0      7
# 2           1    3.0   78.342215   47.671972           10.0      2
# 3           1    1.0   40.409907   32.781260            1.0     10
# 4          94    2.0   64.285067   38.562517            9.0     16
#
#    HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  Social_1  Social_2  \
# 0        10.0       2014   0.075424          0  ...        11      3097
# 1         8.0       1966   0.118537          0  ...        30      6207
# 2        17.0       1988   0.025609          0  ...        33      5261
# 3        22.0       1977   0.007122          0  ...         1       264
# 4        16.0       1972   0.282798          0  ...        33      8667
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price  \
# 0         0         900.0            0        0        0  305018.871089
# 1         1        1183.0            1        0        0  177734.553407
# 2         0         240.0            3        1        0  282078.720850
# 3         0         900.0            0        1        0  168106.007630
# 4         2         900.0            0        6        0  343995.102962
#
#    LifeSquare_nan  Healthcare_1_nan
# 0               1                 1
# 1               0                 0
# 2               0                 0
# 3               1                 1
# 4               0                 1
#
# [5 rows x 21 columns]

# %% [markdown]
# # Добавление новых признаков

# %% [markdown]
# #### Слияние Social_1 и Social_2

# %%
df['Social_1_2'] = (df['Social_2'] / 200) + df['Social_1']

# %%
df.drop(['Social_1', 'Social_2'], axis=1, inplace=True)

# %%
df['Social_1_2']
# Out:
# 0        26.485
# 1        61.035
# 2        59.305
# 3         2.320
# 4        76.335
#          ...
# 9995    103.555
# 9996      5.145
# 9997     41.930
# 9998     87.020
# 9999     85.145
# Name: Social_1_2, Length: 10000, dtype: float64

# %% [markdown]
# #### Категоризация этажей квартир

# %%
df['LifeSquare/Square'] = (df['LifeSquare'] / df['Square'])
df['LifeSquare/Square'].median()
# Out:
# 0.6132264297990705

# %%
df['HouseFloor/Floor'] = ( df['HouseFloor'] / df['Floor'])
df['HouseFloor/Floor'].describe()
# Out:
# count    10000.000000
# mean         2.163558
# std          1.892261
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          2.428571
# max         20.000000
# Name: HouseFloor/Floor, dtype: float64

# %%
def floor_to_cat(X):
    
    X['floor_cat'] = 0
    
    X.loc[(X['HouseFloor/Floor'] == 1) & (X['Floor'] == 1), 'floor_cat'] = 1
    X.loc[(X['HouseFloor/Floor'] == 1) & (X['Floor'] == 2), 'floor_cat'] = 2
    X.loc[(X['HouseFloor/Floor'] >= 2.5) & (X['Floor'] > 2), 'floor_cat'] = 3
    X.loc[(X['HouseFloor/Floor'] >= 2) & (X['HouseFloor/Floor'] < 2.5), 'floor_cat'] = 4
    X.loc[(X['HouseFloor/Floor'] >= 2.5) & (X['Floor'] <= 2), 'floor_cat'] = 5
    X.loc[(X['HouseFloor/Floor'] >= 1.5) & (X['HouseFloor/Floor'] < 2), 'floor_cat'] = 6
    X.loc[(X['HouseFloor/Floor'] > 1) & (X['HouseFloor/Floor'] < 1.5), 'floor_cat'] = 7
    X.loc[(X['HouseFloor/Floor'] == 1) & (X['Floor'] > 2), 'floor_cat'] = 8
    
    return X

# %%
df = floor_to_cat(df)
df
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0             27    3.0  52.513310   32.781260           10.0    4.0
# 1             22    1.0  39.832524   23.169223            8.0    7.0
# 2              1    3.0  78.342215   47.671972           10.0    2.0
# 3              1    1.0  40.409907   32.781260            1.0   10.0
# 4             94    2.0  64.285067   38.562517            9.0   16.0
# ...          ...    ...        ...         ...            ...    ...
# 9995          61    2.0  49.090728   33.272626            6.0    3.0
# 9996          27    2.0  64.307684   37.038420            9.0   13.0
# 9997         178    1.0  52.513310   16.555363            5.0    3.0
# 9998          21    1.0  32.330292   22.326870            5.0    3.0
# 9999          94    1.0  35.815476   22.301367            6.0    9.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  LifeSquare_outlier  \
# 0           10.0       2014   0.075424          0  ...                   0
# 1            8.0       1966   0.118537          0  ...                   0
# 2           17.0       1988   0.025609          0  ...                   0
# 3           22.0       1977   0.007122          0  ...                   0
# 4           16.0       1972   0.282798          0  ...                   0
# ...          ...        ...        ...        ...  ...                 ...
# 9995        12.0       1981   0.300323          0  ...                   0
# 9996        13.0       1977   0.072158          0  ...                   0
# 9997         5.0       1977   0.460556          0  ...                   0
# 9998         9.0       1969   0.194489          0  ...                   0
# 9999         9.0       1975   0.127376          0  ...                   0
#
#       KitchenSquare_outlier  NonresidentialSquare  HouseFloor_outlier  \
# 0                         0              9.732050                   0
# 1                         0              8.663301                   0
# 2                         0             20.670243                   0
# 3                         0              6.628647                   0
# 4                         0             16.722551                   0
# ...                     ...                   ...                 ...
# 9995                      0              9.818102                   0
# 9996                      0             18.269264                   1
# 9997                      0             30.957946                   0
# 9998                      0              5.003423                   0
# 9999                      0              7.514109                   0
#
#       Floor_outlier  HouseYear_outlier  Social_1_2  LifeSquare/Square  \
# 0                 0                  0      26.485           0.624247
# 1                 0                  0      61.035           0.581666
# 2                 0                  0      59.305           0.608509
# 3                 0                  0       2.320           0.811218
# 4                 0                  0      76.335           0.599867
# ...             ...                ...         ...                ...
# 9995              0                  0     103.555           0.677778
# 9996              0                  0       5.145           0.575956
# 9997              0                  1      41.930           0.315260
# 9998              0                  0      87.020           0.690587
# 9999              0                  0      85.145           0.622674
#
#       HouseFloor/Floor  floor_cat
# 0             2.500000          3
# 1             1.142857          7
# 2             8.500000          5
# 3             2.200000          4
# 4             1.000000          8
# ...                ...        ...
# 9995          4.000000          3
# 9996          1.000000          8
# 9997          1.666667          6
# 9998          3.000000          3
# 9999          1.000000          8
#
# [10000 rows x 31 columns]

# %%
def cottage_to_binary_cat(X):
    
    X['cottage'] = 0
    X.loc[X['HouseFloor'] == 1, 'cottage'] = 1
    
    return X

# %%
df = cottage_to_binary_cat(df)
df.sample(5)
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4798          44    1.0  33.940012   22.480856            5.0    4.0
# 2830          27    1.0  49.777210   19.150213            1.0    1.0
# 1214           2    3.0  62.151384   43.557635            6.0    9.0
# 5203         187    1.0  40.075777   17.729285           10.0    8.0
# 1965           1    3.0  75.714111   45.727985           10.0   16.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  KitchenSquare_outlier  \
# 4798         5.0       1968   0.232205          0  ...                      0
# 2830         1.0       2014   0.017647          0  ...                      0
# 1214         9.0       1970   0.309479          0  ...                      0
# 5203        16.0       2004   0.041116          0  ...                      0
# 1965        17.0       1994   0.025609          0  ...                      0
#
#       NonresidentialSquare  HouseFloor_outlier  Floor_outlier  \
# 4798              6.459155                   0              0
# 2830             29.626997                   0              1
# 1214             12.593749                   0              0
# 5203             12.346492                   0              0
# 1965             19.986127                   0              0
#
#       HouseYear_outlier  Social_1_2  LifeSquare/Square  HouseFloor/Floor  \
# 4798                  0      48.300           0.662370            1.2500
# 2830                  0       4.345           0.384718            1.0000
# 1214                  0      73.575           0.700831            1.0000
# 5203                  0     127.460           0.442394            2.0000
# 1965                  0      59.305           0.603956            1.0625
#
#       floor_cat  cottage
# 4798          7        0
# 2830          1        1
# 1214          8        0
# 5203          4        0
# 1965          7        0
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Категоризация возраста дома

# %%
df['house_age'] = 2021 - df['HouseYear']

# %%
df.sample(10)
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1340           1    1.0  42.813865   19.585386            8.0   15.0
# 7901          39    1.0  33.682376   21.601503            6.0    9.0
# 2093         190    2.0  47.489415   35.564479            4.0    5.0
# 7795          27    2.0  63.735421   34.021634           12.0   14.0
# 6575          34    2.0  58.201414   33.413218           10.0   14.0
# 6560           1    2.0  52.230780   32.781260            1.0   10.0
# 6111           7    2.0  39.019358   22.770349            7.0    9.0
# 2590           1    3.0  88.098352   32.781260            1.0   20.0
# 1369           1    3.0  62.734894   41.183185            8.0    8.0
# 2863          77    1.0  42.678844   23.918634            8.0   12.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  NonresidentialSquare  \
# 1340        17.0       1991   0.025609          0  ...             15.228479
# 7901         9.0       1973   0.428826          0  ...              6.080873
# 2093         5.0       1977   0.000000          0  ...              7.924936
# 7795        17.0       1977   0.011654          0  ...             17.713787
# 6575        17.0       1999   0.069753          0  ...             14.788196
# 6560        17.0       1977   0.007122          0  ...             18.449520
# 6111         9.0       1967   0.035145          0  ...              9.249009
# 2590        20.0       1977   0.007122          0  ...             54.317092
# 1369        14.0       1992   0.025609          0  ...             13.551709
# 2863        12.0       1983   0.000070          0  ...             10.760210
#
#       HouseFloor_outlier  Floor_outlier  HouseYear_outlier  Social_1_2  \
# 1340                   0              0                  0      59.305
# 7901                   0              1                  0      50.055
# 2093                   0              0                  1      67.690
# 7795                   0              0                  0       8.575
# 6575                   0              0                  0     121.350
# 6560                   0              0                  0       2.320
# 6111                   0              1                  0      88.460
# 2590                   0              1                  0       2.320
# 1369                   0              0                  0      59.305
# 2863                   0              1                  0      97.545
#
#       LifeSquare/Square  HouseFloor/Floor  floor_cat  cottage  house_age
# 1340           0.457454          1.133333          7        0         30
# 7901           0.641330          1.000000          8        0         48
# 2093           0.748893          1.000000          8        0         44
# 7795           0.533795          1.214286          7        0         44
# 6575           0.574096          1.214286          7        0         22
# 6560           0.627623          1.700000          6        0         44
# 6111           0.583565          1.000000          8        0         54
# 2590           0.372098          1.000000          8        0         44
# 1369           0.656464          1.750000          6        0         29
# 2863           0.560433          1.000000          8        0         38
#
# [10 rows x 33 columns]

# %%
def age_to_cat(X):
    
    X['age_cat'] = 0
    
    X.loc[df['house_age'] <= 5, 'age_cat'] = 1
    X.loc[(df['house_age'] > 5) & (df['house_age'] <= 10), 'age_cat'] = 2
    X.loc[(df['house_age'] > 10) & (df['house_age'] <= 15), 'age_cat'] = 3
    X.loc[(df['house_age'] > 15) & (df['house_age'] <= 25), 'age_cat'] = 4
    X.loc[(df['house_age'] > 25) & (df['house_age'] <= 40), 'age_cat'] = 5
    X.loc[(df['house_age'] > 40) & (df['house_age'] <= 45), 'age_cat'] = 6
    X.loc[(df['house_age'] > 45) & (df['house_age'] <= 55), 'age_cat'] = 7
    X.loc[(df['house_age'] > 55), 'age_cat'] = 8
    
    return X

# %%
df = age_to_cat(df)
df.head(10)
# Out:
#    DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0          27    3.0  52.513310   32.781260           10.0    4.0        10.0
# 1          22    1.0  39.832524   23.169223            8.0    7.0         8.0
# 2           1    3.0  78.342215   47.671972           10.0    2.0        17.0
# 3           1    1.0  40.409907   32.781260            1.0   10.0        22.0
# 4          94    2.0  64.285067   38.562517            9.0   16.0        16.0
# 5          99    3.0  62.528465   47.103833            6.0    9.0         9.0
# 6          44    1.0  33.938750   21.772930            9.0    1.0        12.0
# 7          59    2.0  50.391814   32.893256            8.0    8.0        17.0
# 8           1    1.0  46.887892   44.628132            1.0   12.0        20.0
# 9           6    3.0  79.867477   75.085125            1.0    3.0        17.0
#
#    HouseYear  Ecology_1  Ecology_2  ...  HouseFloor_outlier  Floor_outlier  \
# 0       2014   0.075424          0  ...                   0              0
# 1       1966   0.118537          0  ...                   0              0
# 2       1988   0.025609          0  ...                   0              0
# 3       1977   0.007122          0  ...                   0              0
# 4       1972   0.282798          0  ...                   0              0
# 5       1972   0.012339          0  ...                   0              0
# 6       1968   0.232205          0  ...                   0              0
# 7       1986   0.019509          0  ...                   0              0
# 8       1977   0.007122          0  ...                   0              0
# 9       2014   0.243205          0  ...                   0              0
#
#    HouseYear_outlier  Social_1_2  LifeSquare/Square  HouseFloor/Floor  \
# 0                  0      26.485           0.624247          2.500000
# 1                  0      61.035           0.581666          1.142857
# 2                  0      59.305           0.608509          8.500000
# 3                  0       2.320           0.811218          2.200000
# 4                  0      76.335           0.599867          1.000000
# 5                  0      63.880           0.753318          1.000000
# 6                  0      48.300           0.641536         12.000000
# 7                  0      75.435           0.652750          2.125000
# 8                  0       2.320           0.951805          1.666667
# 9                  0      12.820           0.940121          5.666667
#
#    floor_cat  cottage  house_age  age_cat
# 0          3        0          7        2
# 1          7        0         55        7
# 2          5        0         33        5
# 3          4        0         44        6
# 4          8        0         49        7
# 5          8        0         49        7
# 6          5        0         53        7
# 7          4        0         35        5
# 8          6        0         44        6
# 9          3        0          7        2
#
# [10 rows x 34 columns]

# %% [markdown]
# # Уменьшение количества занимаемой памяти базы

# %%
reduce_mem_usage(df)
# Out:
# Memory usage of dataframe is 2.48 MB
# Memory usage after optimization is: 0.72 MB
# Decreased by 70.765747%
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0             27    3.0  52.513309   32.781261           10.0    4.0
# 1             22    1.0  39.832523   23.169222            8.0    7.0
# 2              1    3.0  78.342216   47.671970           10.0    2.0
# 3              1    1.0  40.409908   32.781261            1.0   10.0
# 4             94    2.0  64.285065   38.562515            9.0   16.0
# ...          ...    ...        ...         ...            ...    ...
# 9995          61    2.0  49.090729   33.272625            6.0    3.0
# 9996          27    2.0  64.307686   37.038422            9.0   13.0
# 9997         178    1.0  52.513309   16.555363            5.0    3.0
# 9998          21    1.0  32.330292   22.326870            5.0    3.0
# 9999          94    1.0  35.815475   22.301367            6.0    9.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  ...  HouseFloor_outlier  \
# 0           10.0       2014   0.075424          0  ...                   0
# 1            8.0       1966   0.118537          0  ...                   0
# 2           17.0       1988   0.025609          0  ...                   0
# 3           22.0       1977   0.007122          0  ...                   0
# 4           16.0       1972   0.282798          0  ...                   0
# ...          ...        ...        ...        ...  ...                 ...
# 9995        12.0       1981   0.300323          0  ...                   0
# 9996        13.0       1977   0.072158          0  ...                   1
# 9997         5.0       1977   0.460556          0  ...                   0
# 9998         9.0       1969   0.194489          0  ...                   0
# 9999         9.0       1975   0.127376          0  ...                   0
#
#       Floor_outlier  HouseYear_outlier  Social_1_2  LifeSquare/Square  \
# 0                 0                  0   26.485001           0.624247
# 1                 0                  0   61.035000           0.581666
# 2                 0                  0   59.305000           0.608509
# 3                 0                  0    2.320000           0.811218
# 4                 0                  0   76.334999           0.599867
# ...             ...                ...         ...                ...
# 9995              0                  0  103.555000           0.677778
# 9996              0                  0    5.145000           0.575956
# 9997              0                  1   41.930000           0.315260
# 9998              0                  0   87.019997           0.690587
# 9999              0                  0   85.144997           0.622674
#
#       HouseFloor/Floor  floor_cat  cottage  house_age  age_cat
# 0             2.500000          3        0          7        2
# 1             1.142857          7        0         55        7
# 2             8.500000          5        0         33        5
# 3             2.200000          4        0         44        6
# 4             1.000000          8        0         49        7
# ...                ...        ...      ...        ...      ...
# 9995          4.000000          3        0         40        5
# 9996          1.000000          8        0         44        6
# 9997          1.666667          6        0         44        6
# 9998          3.000000          3        0         52        7
# 9999          1.000000          8        0         46        7
#
# [10000 rows x 34 columns]

# %% [markdown]
# ### Анализ признаков

# %%
df_num_features = df.select_dtypes(include=['float64', 'float32', 'float16'])
df_num_features.drop('Price', axis=1, inplace=True)

# %%
df_num_features.head()
# Out:
#    Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  Ecology_1  \
# 0    3.0  52.513309   32.781261           10.0    4.0        10.0   0.075424
# 1    1.0  39.832523   23.169222            8.0    7.0         8.0   0.118537
# 2    3.0  78.342216   47.671970           10.0    2.0        17.0   0.025609
# 3    1.0  40.409908   32.781261            1.0   10.0        22.0   0.007122
# 4    2.0  64.285065   38.562515            9.0   16.0        16.0   0.282798
#
#    Healthcare_1  NonresidentialSquare  Social_1_2  LifeSquare/Square  \
# 0         900.0              9.732050   26.485001           0.624247
# 1        1183.0              8.663301   61.035000           0.581666
# 2         240.0             20.670244   59.305000           0.608509
# 3         900.0              6.628647    2.320000           0.811218
# 4         900.0             16.722551   76.334999           0.599867
#
#    HouseFloor/Floor
# 0          2.500000
# 1          1.142857
# 2          8.500000
# 3          2.200000
# 4          1.000000

# %%
df_num_features.hist(figsize=(16, 16), bins=20, grid=False)
plt.show()

# %%
df['LifeSquare/Square'].describe()
# Out:
# count    10000.000000
# mean         0.619002
# std          0.122064
# min          0.284195
# 25%          0.544510
# 50%          0.613226
# 75%          0.683176
# max          0.999712
# Name: LifeSquare/Square, dtype: float64

# %%
count_rooms = sns.jointplot(df['Price'], df['Social_1_2'], kind='reg')
count_rooms.fig.set_figwidth(8)
count_rooms.fig.set_figheight(8)

plt.show()

# %%
counts = df['age_cat'].value_counts()

plt.figure(figsize=(12, 8))
plt.title('age_cat')
sns.barplot(counts.index, counts.values)

plt.show()

# %%
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.4)

corr_matrix = df.corr()
corr_matrix = np.round(corr_matrix, 2)
corr_matrix[np.abs(corr_matrix) < 0.4] = 0

sns.heatmap(corr_matrix, annot=True, linewidth=.5, cmap='coolwarm')

plt.title('Colleration matrix')
plt.show()

# %%
df.drop('HouseYear', axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
y = pd.DataFrame(df['Price'], columns=['Price'])
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   10000 non-null  float32
# dtypes: float32(1)
# memory usage: 39.2 KB

# %%
x = df.drop('Price', axis=1)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train.to_pickle('x_train.pkl')
y_train.to_pickle('y_train.pkl')

x_valid.to_pickle('x_valid.pkl')
y_valid.to_pickle('y_valid.pkl')
